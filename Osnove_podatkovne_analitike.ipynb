# %% [markdown]
# <a href="https://colab.research.google.com/github/klaradavidson/osnovePodatkovneAnalitike/blob/main/Osnove_podatkovne_analitike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello!")
